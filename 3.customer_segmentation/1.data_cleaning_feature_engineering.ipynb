# %% [markdown]
# # Data Cleaning & Feature Engineering
# Data cleaning is not the sexiest part of Machine Learning, but it's the part that takes the longest time and the most iterations. It's also one of three most important things that affect your results:
# 1. Data
# 2. Features
# 3. Model
#
# **Better data beats fancier algorithms.** Therefore it is *critial* to take a substantial amount of time in this part of Machine Learning, as it also allows the data scientist to really understand and make discoveries about the data.

# %% [markdown]
# ### Download the data

# %% [markdown]
# The data can be downloaded from UCI's Machine Learning Repository: http://archive.ics.uci.edu/ml/machine-learning-databases/00352/

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# ### Import data

# %%
# I like to track how long time codes take to run - especially when running models

start = datetime.now()

df_original = pd.read_excel('../3.customer_segmentation/data/Online Retail.xlsx')

end = datetime.now()
print(end - start)
# Out:
# 0:00:47.144645

# %%
# Make a copy of the dataframe so we have an original version to compare with, as we make changes to the dataframe

df = df_original

# %%
df.sample(2)
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 243153   C558422     23300  GARDENERS KNEELING PAD CUP OF TEA         -1
# 488635    577844     22383              LUNCH BAG SUKI DESIGN          4
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 243153 2011-06-29 11:54:00       1.65     16779.0  United Kingdom
# 488635 2011-11-22 10:41:00       4.96         NaN  United Kingdom

# %% [markdown]
# ### Clean data
# Go through each column and clean/explore the data.

# %%
list(df.columns)
# Out:
# ['InvoiceNo',
#  'StockCode',
#  'Description',
#  'Quantity',
#  'InvoiceDate',
#  'UnitPrice',
#  'CustomerID',
#  'Country']

# %% [markdown]
# ### Clean column (feature): Quantity
#  <s>'InvoiceNo',</s>
#  <s>'StockCode',</s>
#  <s>'Description',</s>
#  **'Quantity',**
#  'InvoiceDate',
#  'UnitPrice',
#  'CustomerID',
#  'Country'

# %%
df['Quantity'].describe()
# Out:
# count    541909.000000
# mean          9.552250
# std         218.081158
# min      -80995.000000
# 25%           1.000000
# 50%           3.000000
# 75%          10.000000
# max       80995.000000
# Name: Quantity, dtype: float64

# %%
df[df['Quantity'] < 0].sample()
# Out:
#        InvoiceNo StockCode          Description  Quantity         InvoiceDate  \
# 352787   C567690     20728  LUNCH BAG CARS BLUE        -6 2011-09-21 17:01:00
#
#         UnitPrice  CustomerID         Country
# 352787       1.65     15810.0  United Kingdom

# %% [markdown]
# Only keep columns with positive values

# %%
# It's always good to check the size before dropping data

df.shape
# Out:
# (541909, 8)

# %%
df = df[(df['Quantity']>0)]
df.shape
# Out:
# (531285, 8)

# %% [markdown]
# ### Clean column: InvoiceDate
#  <s>'InvoiceNo',</s>
#  <s>'StockCode',</s>
#  <s>'Description',</s>
#  <s>'Quantity',</s>
#  **'InvoiceDate',**
#  'UnitPrice',
#  'CustomerID',
#  'Country'

# %%
# Check datatype to see if we need to convert it (e.g. from string to datetime)

df['InvoiceDate'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# Great! `InvoiceDate` is a datetime data type. No need to convert.

# %%
df['InvoiceDate'].describe()
# Out:
# count                  531285
# unique                  19052
# top       2011-10-31 14:41:00
# freq                     1114
# first     2010-12-01 08:26:00
# last      2011-12-09 12:50:00
# Name: InvoiceDate, dtype: object

# %% [markdown]
# There's a little over one year's worth of data in the downloaded dataset. To keep things tidy let's restrict the data range to one full year.
#
# One way we can do this is to identify the cut-off date, Loop through each row and if the date is after our cutoff date, we can assign *drop == yes* to it and then drop it. The process would look like this:
#
# 1. Create a for-loop that goes through each row and compares InvoiceDate with cutoff_date
# 2. If date is greater than cutoff_date, assign `df['drop'] == "yes"` to that row
# 3. Drop rows where *drop == yes*

# %%
from datetime import timedelta

# %%
# Find out what the cutoff date is (1 year after the earliest date)

df['InvoiceDate'].min() + timedelta(days=365)
# Out:
# Timestamp('2011-12-01 08:26:00')

# %%
cutoff_date = df['InvoiceDate'].min() + timedelta(days=365)

# %%
# Create a new column that we will use to identify whether or not we should drop the row

df['drop'] = "tbd"
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df['drop'] = "tbd"

# %%
# This would work, but computationally expensive. Try running it and check `docker stats`

for i in df['InvoiceDate']:
    if i > cutoff_date:
        df['drop'] == "yes"
    else:
        df['drop'] == "no"
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-74-6bb806e17989> in <module>()
#       3         df['drop'] == "yes"
#       4     else:
# ----> 5         df['drop'] == "no"
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     853
#     854             with np.errstate(all='ignore'):
# --> 855                 res = na_op(values, other)
#     856             if isscalar(res):
#     857                 raise TypeError('Could not compare %s type with Series' %
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     757
#     758         if is_object_dtype(x.dtype):
# --> 759             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     760         else:
#     761
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#     737         result = lib.vec_compare(x, y, op)
#     738     else:
# --> 739         result = lib.scalar_compare(x, y, op)
#     740     return result
#     741
#
# KeyboardInterrupt:

# %% [markdown]
# As a data scientist, it's important to understand your computer's processing power and know how to employ efficient techniques. The method above maxes out our CPU to 100% and it takes forever to run, especially with larger datasets. CPU is expensive and you don't want to have to pay for more powerful machines when you can just adjust your code.

# %%
df = df.drop('drop', axis=1)

# %%
# Try a more efficient way and see how much faster it cmomputes

df[df['InvoiceDate'] > cutoff_date].tail(2)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France

# %%
df.shape
# Out:
# (531285, 8)

# %%
(df[df['InvoiceDate'] > cutoff_date]).shape
# Out:
# (25135, 8)

# %%
# If we drop these rows correctly, we should end up with 506150 rows of data

531285 - 25135
# Out:
# 506150

# %%
df = df[~(df['InvoiceDate'] > cutoff_date)]

# %%
# Alternatively, you can do
# df = df[(df['InvoiceDate'] < cutoff_date)]

# %%
df.shape
# Out:
# (506150, 8)

# %% [markdown]
# ### Clean column: UnitPrice
#  <s>'InvoiceNo',</s>
#  <s>'StockCode',</s>
#  <s>'Description',</s>
#  <s>'Quantity',</s>
#  <s>'InvoiceDate',</s>
#  **'UnitPrice',**
#  'CustomerID',
#  'Country'

# %%
df['UnitPrice'].describe()
# Out:
# count    506150.000000
# mean          3.848195
# std          42.150519
# min      -11062.060000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max       13541.330000
# Name: UnitPrice, dtype: float64

# %%
df[df['UnitPrice'] < 0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
df[df['UnitPrice'] == 0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 622       536414     22139                               NaN        56
# 1970      536545     21134                               NaN         1
# 1971      536546     22145                               NaN         1
# 1972      536547     37509                               NaN         1
# 1987      536549    85226A                               NaN         1
# 1988      536550     85044                               NaN         1
# 2024      536552     20950                               NaN         1
# 2025      536553     37461                               NaN         3
# 2026      536554     84670                               NaN        23
# 4348      536765    84952C                               NaN        19
# 6391      536941     22734                            amazon        20
# 6392      536942     22139                            amazon        15
# 7187      536995     35951                               NaN        57
# 7191      536999     21421                               NaN       110
# 7194      537002     21651                               NaN        70
# 9302      537197     22841      ROUND CAKE TIN VINTAGE GREEN         1
# 12008     537361     21777                               NaN         5
# 13263     537430     85215                               NaN       120
# 13961  2010-12-06 17:00:00        0.0         NaN  United Kingdom
# 13962  2010-12-06 17:01:00        0.0         NaN  United Kingdom
# 14335  2010-12-07 11:48:00        0.0         NaN  United Kingdom
# 14336  2010-12-07 11:48:00        0.0         NaN  United Kingdom
# 14337  2010-12-07 11:48:00        0.0         NaN  United Kingdom
# 14338  2010-12-07 11:48:00        0.0         NaN  United Kingdom
# 14339  2010-12-07 11:48:00        0.0         NaN  United Kingdom
# 14340  2010-12-07 11:48:00        0.0         NaN  United Kingdom
# 14341  2010-12-07 11:48:00        0.0         NaN  United Kingdom
# 14342  2010-12-07 11:48:00        0.0         NaN  United Kingdom
# ...                    ...        ...         ...             ...
# 489201 2011-11-22 12:12:00        0.0         NaN  United Kingdom
# 489202 2011-11-22 12:12:00        0.0         NaN  United Kingdom
# 489203 2011-11-22 12:12:00        0.0         NaN  United Kingdom
# 489204 2011-11-22 12:12:00        0.0         NaN  United Kingdom
# 489205 2011-11-22 12:13:00        0.0         NaN  United Kingdom
# 495917 2011-11-24 09:06:00        0.0         NaN  United Kingdom
# 495918 2011-11-24 09:07:00        0.0         NaN  United Kingdom
# 495919 2011-11-24 09:07:00        0.0         NaN  United Kingdom
# 495929 2011-11-24 09:07:00        0.0         NaN  United Kingdom
# 497301 2011-11-24 10:36:00        0.0         NaN  United Kingdom
# 497489 2011-11-24 11:21:00        0.0         NaN  United Kingdom
# 497677 2011-11-24 12:29:00        0.0         NaN  United Kingdom
# 499156 2011-11-24 15:55:00        0.0         NaN  United Kingdom
# 499157 2011-11-24 15:56:00        0.0         NaN  United Kingdom
# 499169 2011-11-24 16:22:00        0.0         NaN  United Kingdom
# 499785 2011-11-25 09:37:00        0.0         NaN  United Kingdom
# 499786 2011-11-25 09:38:00        0.0         NaN  United Kingdom
# 499787 2011-11-25 09:38:00        0.0         NaN  United Kingdom
# 499887 2011-11-25 10:49:00        0.0         NaN  United Kingdom
# 502122 2011-11-25 15:57:00        0.0     13256.0  United Kingdom
# 503634 2011-11-27 12:39:00        0.0         NaN  United Kingdom
# 508796 2011-11-29 10:00:00        0.0         NaN  United Kingdom
# 508834 2011-11-29 10:02:00        0.0         NaN  United Kingdom
# 511451 2011-11-29 16:14:00        0.0         NaN  United Kingdom
# 513790 2011-11-30 11:41:00        0.0         NaN  United Kingdom
# 514180 2011-11-30 13:29:00        0.0         NaN  United Kingdom
# 514651 2011-11-30 14:26:00        0.0         NaN  United Kingdom
# 516171 2011-11-30 17:00:00        0.0         NaN  United Kingdom
# 516188 2011-11-30 17:13:00        0.0         NaN  United Kingdom
# 516189 2011-11-30 17:14:00        0.0         NaN  United Kingdom
#
# [1155 rows x 8 columns]

# %%
# Only keep columns with positive values

df.shape
# Out:
# (506150, 8)

# %%
df = df[(df['UnitPrice']>0)]
df.shape
# Out:
# (504993, 8)

# %% [markdown]
# ### Clean column: CustomerID
#  <s>'InvoiceNo',</s>
#  <s>'StockCode',</s>
#  <s>'Description',</s>
#  <s>'Quantity',</s>
#  <s>'InvoiceDate',</s>
#  <s>'UnitPrice',</s>
#  **'CustomerID',**
#  'Country'

# %%
# Check the number of null rows per column/feature

df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     124413
# Country             0
# dtype: int64

# %% [markdown]
# Looks like some invoices are missing CustomerID. There are many ways of handling null values, such as filling it with the mean/median/mode. However, since our analysis is based on customers, we will have to drop rows with missing CustomerID.

# %%
# If we were filling null values with measures of central tendencies, we can use .describe to get summary statistics

df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  504993.000000  504993.000000  380580.000000
# mean       10.443963       3.900822   15293.531778
# std       111.109818      35.996179    1712.593737
# min         1.000000       0.001000   12346.000000
# 25%         1.000000       1.250000   13969.000000
# 50%         3.000000       2.080000   15159.000000
# 75%        11.000000       4.130000   16793.000000
# max     74215.000000   13541.330000   18287.000000

# %%
# Drop columns that contain null values for CustomerID

df = df.dropna(subset=['CustomerID'], axis=0)

# %%
df.shape
# Out:
# (380580, 8)

# %% [markdown]
# ### Clean column: Country
#  <s>'InvoiceNo',</s>
#  <s>'StockCode',</s>
#  <s>'Description',</s>
#  <s>'Quantity',</s>
#  <s>'InvoiceDate',</s>
#  <s>'UnitPrice',</s>
#  <s>'CustomerID',</s>
#  **'Country'**

# %% [markdown]
# Let's see what countries place the most orders...this will require playing around with the dataframe by slicing (aka indexing), grouping (`df.groupby`) and sorting (`df.sort_values`).

# %%
# See how many unique values are in `Country`

df['Country'].nunique()
# Out:
# 37

# %%
# Why are we missing one Country?

df_original['Country'].nunique()
# Out:
# 38

# %%
# Find out which Country is missing

set(df_original['Country']) - set(df['Country'])
# Out:
# {'Hong Kong'}

# %%
# Explore that Country's data

df_original[df_original['Country']=='Hong Kong']
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 69623     541975     22620          4 TRADITIONAL SPINNING TOPS        60
# 69624     541975    85183B  CHARLIE & LOLA WASTEPAPER BIN FLORA         6
# 69625     541975    85183A   CHARLIE & LOLA WASTEPAPER BIN BLUE         6
# 69626     541975     16236                 KITTY PENCIL ERASERS        28
# 69627     541975     21058               PARTY INVITES WOODLAND        12
# 69628     541975     21967             PACK OF 12 SKULL TISSUES        24
# 69629     541975     21981         PACK OF 12 WOODLAND TISSUES         24
# 69630     541975     22553               PLASTERS IN TIN SKULLS        36
# 69631     541975     22556       PLASTERS IN TIN CIRCUS PARADE         36
# 69632     541975     22554     PLASTERS IN TIN WOODLAND ANIMALS        36
# 69633     541975     22551             PLASTERS IN TIN SPACEBOY        36
# 69634     541975     21947            SET OF 6 HEART CHOPSTICKS        36
# 69635     541975     21948             SET OF 6 CAKE CHOPSTICKS        36
# 69636     541975     21949       SET OF 6 STRAWBERRY CHOPSTICKS        36
# 69637     541975     22636   CHILDS BREAKFAST SET CIRCUS PARADE         6
# 69638     541975     22634       CHILDS BREAKFAST SET SPACEBOY          6
# 69639     541975     22635     CHILDS BREAKFAST SET DOLLY GIRL          6
# 69640     541975     21246               RED RETROSPOT BIG BOWL        12
# 69641     541975     20677                   PINK POLKADOT BOWL        24
# 69642     541975     20676                   RED RETROSPOT BOWL        24
# 69643     541975     20675                   BLUE POLKADOT BOWL        24
# 69644     541975    84997D    PINK 3 PIECE POLKADOT CUTLERY SET        24
# 69645     541975    84997C    BLUE 3 PIECE POLKADOT CUTLERY SET        24
# 69646     541975    84997B    RED 3 PIECE RETROSPOT CUTLERY SET        24
# 69647     541975     21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         4
# 69648     541975     22204               MILK PAN BLUE POLKADOT         4
# 69649     541975     22203               MILK PAN RED RETROSPOT         4
# 69650     541975     22202               MILK PAN PINK POLKADOT         4
# 69651     541975     22630                 DOLLY GIRL LUNCH BOX        12
# 69652     541975     22629                  SPACEBOY LUNCH BOX         12
# ...          ...       ...                                  ...       ...
# 403605    571652     22716                   CARD CIRCUS PARADE        12
# 403606    571652     22580         ADVENT CALENDAR GINGHAM SACK         3
# 403607    571652     22947           WOODEN ADVENT CALENDAR RED         2
# 403608    571652     21731        RED TOADSTOOL LED NIGHT LIGHT        12
# 403609    571652     22779           WOODEN OWLS LIGHT GARLAND          4
# 403610    571652     21744      SNOWFLAKE PORTABLE TABLE LIGHT          6
# 403611    571652     22780       LIGHT GARLAND BUTTERFILES PINK         4
# 403612    571652    85179A              GREEN BITTY LIGHT CHAIN         3
# 403613    571652     21829           DINOSAUR KEYRINGS ASSORTED        36
# 403614    571652     20819                    SILVER TEDDY BEAR         4
# 403615    571652     21055                   TOOL BOX SOFT TOY          1
# 403616    571652     22138        BAKING SET 9 PIECE RETROSPOT          3
# 403617    571652     22139     RETROSPOT TEA SET CERAMIC 11 PC          3
# 403618    571652     23348    CHILDRENS TOY COOKING UTENSIL SET         6
# 403619    571652     21915               RED  HARMONICA IN BOX         12
# 403620    571652     22550                     HOLIDAY FUN LUDO         4
# 403621    571652     21912             VINTAGE SNAKES & LADDERS         4
# 403622    571652     22622       BOX OF VINTAGE ALPHABET BLOCKS         2
# 403623    571652     22433          WATERING CAN GREEN DINOSAUR         6
# 403624    571652     23155  KNICKERBOCKERGLORY MAGNET ASSORTED         12
# 403625    571652     23077                  DOUGHNUT LIP GLOSS         20
# 423772    573154     22139     RETROSPOT TEA SET CERAMIC 11 PC         12
# 423773    573154     21915               RED  HARMONICA IN BOX         24
# 423774    573154     22620          4 TRADITIONAL SPINNING TOPS        24
# 423775    573154     22619            SET OF 6 SOLDIER SKITTLES        12
# 423776    573154     22452         MEASURING TAPE BABUSHKA PINK        30
# 423777    573154     22492              MINI PAINT SET VINTAGE         36
# 423778    573154     23328   SET 6 SCHOOL MILK BOTTLES IN CRATE         8
# 465423   C576233         M                               Manual        -1
# 465424    576234         M                               Manual         1
#
#                InvoiceDate  UnitPrice  CustomerID    Country
# 69623  2011-01-24 14:24:00       1.25         NaN  Hong Kong
# 69624  2011-01-24 14:24:00       3.75         NaN  Hong Kong
# 69625  2011-01-24 14:24:00       3.75         NaN  Hong Kong
# 69626  2011-01-24 14:24:00       0.21         NaN  Hong Kong
# 69627  2011-01-24 14:24:00       0.85         NaN  Hong Kong
# 69628  2011-01-24 14:24:00       0.29         NaN  Hong Kong
# 69629  2011-01-24 14:24:00       0.29         NaN  Hong Kong
# 69630  2011-01-24 14:24:00       1.65         NaN  Hong Kong
# 69631  2011-01-24 14:24:00       1.65         NaN  Hong Kong
# 69632  2011-01-24 14:24:00       1.65         NaN  Hong Kong
# 69633  2011-01-24 14:24:00       1.65         NaN  Hong Kong
# 69634  2011-01-24 14:24:00       1.25         NaN  Hong Kong
# 69635  2011-01-24 14:24:00       1.25         NaN  Hong Kong
# 69636  2011-01-24 14:24:00       1.25         NaN  Hong Kong
# 69637  2011-01-24 14:24:00       8.50         NaN  Hong Kong
# 69638  2011-01-24 14:24:00       9.95         NaN  Hong Kong
# 69639  2011-01-24 14:24:00       9.95         NaN  Hong Kong
# %% [markdown]
# ### Feature engineering
# When you use domain knowledge of the data to create features that help the algorithm work better. The quality and quantity of features will have great influence on whether the model is good or not. Choosing the right features can produce simpler and more flexible models, and often yield better results.
#
# Three components that affect results are:
# 1. Data
# 2. Features
# 3. Model

# %%
df['InvoiceDate'].isnull().unique()
# Out:
# array([False], dtype=object)

# %%
df.shape
# Out:
# (380580, 9)

# %%
df['InvoiceDate'].shape
# Out:
# (380580,)

# %%
month_list = []
dayofweek_list = []
hour_list = []

for i in df['InvoiceDate']:
    month_list.append(datetime.date(i).month)
    dayofweek_list.append(datetime.weekday(i))
    hour_list.append(datetime.time(i).hour)

# %%
len(month_list)
# Out:
# 380580

# %%
month_list[380570:380580]
# Out:
# [11, 11, 11, 11, 11, 11, 11, 11, 11, 11]

# %%
pd.Series(month_list)[380570:380580]
# Out:
# 380570    11
# 380571    11
# 380572    11
# 380573    11
# 380574    11
# 380575    11
# 380576    11
# 380577    11
# 380578    11
# 380579    11
# dtype: int64

# %%
df['Month'] = pd.Series(month_list)
df['Dayofweek'] = pd.Series(dayofweek_list)
df['Hour'] = pd.Series(hour_list)

# %%
pd.Series(month_list)
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
# 5         12
# 6         12
# 7         12
# 8         12
# 9         12
# 10        12
# 11        12
# 12        12
# 13        12
# 14        12
# 15        12
# 16        12
# 17        12
# 18        12
# 19        12
# 20        12
# 21        12
# 22        12
# 23        12
# 24        12
# 25        12
# 26        12
# 27        12
# 28        12
# 29        12
#           ..
# 380550    11
# 380551    11
# 380552    11
# 380553    11
# 380554    11
# 380555    11
# 380556    11
# 380557    11
# 380558    11
# 380559    11
# 380560    11
# 380561    11
# 380562    11
# 380563    11
# 380564    11
# 380565    11
# 380566    11
# 380567    11
# 380568    11
# 380569    11
# 380570    11
# 380571    11
# 380572    11
# 380573    11
# 380574    11
# 380575    11
# 380576    11
# 380577    11
# 380578    11
# 380579    11
# dtype: int64

# %%
df.tail()
# Out:
#          index InvoiceNo StockCode                  Description  Quantity  \
# 380575  516364    579885    85034C  3 ROSE MORRIS BOXED CANDLES         4
# 380576  516365    579885     21742  LARGE ROUND WICKER PLATTER          2
# 380577  516366    579885     23084           RABBIT NIGHT LIGHT         6
# 380578  516367    579885     21257  VICTORIAN SEWING BOX MEDIUM         1
# 380579  516368    579885     21259  VICTORIAN SEWING BOX SMALL          1
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Month  \
# 380575 2011-11-30 17:37:00       1.25     15444.0  United Kingdom     11
# 380576 2011-11-30 17:37:00       5.95     15444.0  United Kingdom     11
# 380577 2011-11-30 17:37:00       2.08     15444.0  United Kingdom     11
# 380578 2011-11-30 17:37:00       7.95     15444.0  United Kingdom     11
# 380579 2011-11-30 17:37:00       5.95     15444.0  United Kingdom     11
#
#         Dayofweek  Hour
# 380575          2    17
# 380576          2    17
# 380577          2    17
# 380578          2    17
# 380579          2    17

# %% [markdown]
# ### Export the cleaned data

# %%
from sklearn.externals import joblib

# %%
joblib.dump(df, '../3.customer_segmentation/data/df.p')
# Out:
# ['../3.customer_segmentation/data/df.p']

# %%
joblib.dump(df_original, '../3.customer_segmentation/data/df_original.p')
# Out:
# ['../3.customer_segmentation/data/df_original.p']
